# %%
with open(r"C:\Users\HP\Desktop\PROJECT_MAIN\vita-backend\food_cv\dataset\raw\archive (1)\1HZhs21IE2oNn_V7PF_atNDizdhV8z-vP", "rb") as f:
    print(f.read(16))
# Out:
# b'PK\x03\x04\n\x00\x00\x00\x00\x00f\x8f\xd8T\x00\x00'
